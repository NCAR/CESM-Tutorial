# %% [markdown]
# # Modify CAM output

# %% [markdown]
# <div class="alert alert-info">
# <strong>Exercise: Customize your CAM history files</strong><br><br>
#
# Create a case called `bhistc_high_freq` using the compset `BHISTC_LTso` at resolution `ne16pg3_t201`. Use `--run-unsupported` because the 2 degree resolution is not supported at this stage.
#
# We will interpolate CAM history output to a regular 2° × 2° latitude–longitude grid.
#
# Inaddition to the monthly history file `h0`, tell the model to output the following:
#
# * an `h1` file with instantaneous values of `T`, `Q`, `U`, and `V` every 24 hours.
# * an `h2` file with time-average values of `T`, `Q`, `U`, and `V` every 3 hours.
#
# Set your namelist so that you output:
#
# * a single `h1` file with all the daily output for the month.
# * multiple `h2` files, one for every day of the month.
#
# Your goal is to produce:
#
# * one `h1` file with 31 timesteps.
# * thirty-one `h2` files with 8 timesteps each.
#
# Set the run length to 1 month and make a 1-month run.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <details>
#
# <summary> <font face="Times New Roman" color='blue'>Click here for hints</font> </summary>
#
# **# How do I compile?**
#
# You can compile with the command:
# ```
# qcmd -- ./case.build
# ```
#
# **# How do I control the output?**
#
# Use CAM namelist variables:
#
# ```fortran
# nhtfrq
# mfilt
# fincl
# ```
#
# Use the CAM interpolation settings to interpolate history output to a regular 2° × 2° latitude–longitude grid.
#
# Look at the online documentation for these variables.
#
# **# How do I check my solution?**
#
# When your run is completed, go to the archive directory and navigate to the subdirectory `atm/hist`:
#
# ```bash
# cd /glade/derecho/scratch/$USER/archive/bhistc_high_freq
# cd atm/hist
# ```
#
# (1) Check that your archive directory contains the files:
#
# `h0` files:
#
# ```text
# bhistc_high_freq.cam.h0.0001-01.nc
# ```
#
# `h1` files:
#
# ```text
# bhistc_high_freq.cam.h1.0001-01-01-00000.nc
# bhistc_high_freq.cam.h1.0001-02-01-00000.nc
# ```
#
# `h2` files:
#
# ```text
# bhistc_high_freq.cam.h2.0001-01-01-00000.nc
# …
# bhistc_high_freq.cam.h2.0001-01-31-00000.nc
# bhistc_high_freq.cam.h2.0001-02-01-00000.nc
# ```
#
# (2) Compare the contents of the `h1` and `h2` files using `ncdump`.
#
# ```bash
# ncdump -h bhistc_high_freq.cam.h1.0001-01-01-00000.nc
# ncdump -h bhistc_high_freq.cam.h2.0001-01-01-00000.nc
# ```
#
# (3) Check the number of timesteps in the `h1` and the `h2` files. Look at the sizes of the files.
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <details>
# <summary><font face="Times New Roman" color='blue'>Click here for the solution</font></summary><br>
#
# **# Create a new case**
#
# Create a new case `bhistc_high_freq` with the command:
#
# ```bash
# cd /glade/u/home/$USER/code/my_cesm_code/cime/scripts/
#
# ./create_newcase --case ~/cases/bhistc_high_freq \
#   --compset BHISTC_LTso \
#   --res ne16pg3_t201 \
#   --run-unsupported
# ```
#
# **# Setup**
#
# Invoke `case.setup` with the command:
#
# ```bash
# cd ~/cases/bhistc_high_freq
# ./case.setup
# ```
#
# **# Customize namelists**
#
# Edit the file `user_nl_cam` and add the lines:
#
# ```fortran
#  nhtfrq = 0, -24, -3
#  mfilt = 1, 31, 8
#  fincl2 = 'T:I','Q:I','U:I','V:I'
#  fincl3 = 'T','Q','U','V'
#
#  interpolate_output = .true.
#  interp_output_grid = "2x2"
# ```
#
# Note: For `fincl3`, you could write:
#
# ```fortran
# fincl3 = 'T:A','Q:A','U:A','V:A'
# ```
#
# But since averaging `:A` is the default for these variables, it is not necessary to specify it explicitly.
#
#
# **# Set run length**
#
# Change the run length:
#
# ```bash
# ./xmlchange STOP_N=1,STOP_OPTION=nmonths
# ```
#
#
# **# Change the job queue and account number**
#
# If needed, change `job queue` and `account number`. <br>
# For instance, to run in the queue `tutorial` and the project number ``UESM0015`` (You should use the project number given for this tutorial), use the command:
# ```
# ./xmlchange JOB_QUEUE=tutorial,PROJECT=UESM0015 --force
# ```
#
# **# Build and submit**
#
# Build the model and submit your job:
# ```
# qcmd -- ./case.build
# ./case.submit
# ```
#
# ____
#
# **# Look at your solution**
#
# When the run is completed, look into the archive directory for `bhistc_high_freq`.
#
# (1) Check that your archive directory on derecho contains the history files:
#
# ```bash
# cd /glade/derecho/scratch/$USER/archive/bhistc_high_freq/atm/hist
# ls
# ```
#
# (2) Compare the contents of the `h1` and `h2` files using `ncdump`. Look at the variable attributes. What is the difference between the two files?
#
# ```bash
# ncdump -h bhistc_high_freq.cam.h1.0001-01-01-00000.nc
# ncdump -h bhistc_high_freq.cam.h2.0001-01-01-00000.nc
# ```
#
# The file with the instantaneous output, `h1`, has no `cell_methods` attribute, while the averaged output, `h2`, has the attribute:
#
# ```text
# cell_methods = "time: mean"
# ```
#
# For instance, for the field `Q`.
#
# In the instantaneous file `bhistc_high_freq.cam.h1.0001-01-01-00000.nc`:
#
# ```text
# float Q(time, lev, lat, lon) ;
#                 Q:mdims = 1 ;
#                 Q:units = "kg/kg" ;
#                 Q:mixing_ratio = "wet" ;
#                 Q:long_name = "Specific humidity" ;
# ```
#
# In the time-averaged file `bhistc_high_freq.cam.h2.0001-01-01-00000.nc`:
#
# ```text
# float Q(time, lev, lat, lon) ;
#                 Q:mdims = 1 ;
#                 Q:units = "kg/kg" ;
#                 Q:mixing_ratio = "wet" ;
#                 Q:long_name = "Specific humidity" ;
#                 Q:cell_methods = "time: mean" ;
# ```
#
# (3) Check the number of timesteps in the `h1` and the `h2` files.
#
# `h1` contains 31 time samples. In the netCDF file:
#
# ```text
# time = UNLIMITED ; // (31 currently)
# ```
#
# `h2` contains 8 time samples. In the netCDF file:
#
# ```text
# time = UNLIMITED ; // (8 currently)
# ```
#
# Check the size of the files:
#
# ```bash
# du -skh /glade/derecho/scratch/$USER/archive/bhistc_high_freq/atm/hist/*
# ```
#
#
# </details>
# </div>

# %%
# Look at your solution

When the run is completed, look into the archive directory for `bhistc_high_freq`.

(1) Check that your archive directory on derecho contains the history files:

```bash
cd /glade/derecho/scratch/$USER/archive/bhistc_high_freq/atm/hist
ls
```

(2) Compare the contents of the `h1` and `h2` files using `ncdump`. Look at the variable attributes. What is the difference between the two files?

```bash
ncdump -h bhistc_high_freq.cam.h1.0001-01-01-00000.nc
ncdump -h bhistc_high_freq.cam.h2.0001-01-01-00000.nc
```

The file with the instantaneous output, `h1`, has no `cell_methods` attribute, while the averaged output, `h2`, has the attribute:

```text
cell_methods = "time: mean"
```

For instance, for the field `Q`.

In the instantaneous file `bhistc_high_freq.cam.h1.0001-01-01-00000.nc`:

```text
float Q(time, lev, lat, lon) ;
                Q:mdims = 1 ;
                Q:units = "kg/kg" ;
                Q:mixing_ratio = "wet" ;
                Q:long_name = "Specific humidity" ;
```

In the time-averaged file `bhistc_high_freq.cam.h2.0001-01-01-00000.nc`:

```text
float Q(time, lev, lat, lon) ;
                Q:mdims = 1 ;
                Q:units = "kg/kg" ;
                Q:mixing_ratio = "wet" ;
                Q:long_name = "Specific humidity" ;
                Q:cell_methods = "time: mean" ;
```

(3) Check the number of timesteps in the `h1` and the `h2` files.

`h1` contains 31 time samples. In the netCDF file:

```text
time = UNLIMITED ; // (31 currently)
```

`h2` contains 8 time samples. In the netCDF file:

```text
time = UNLIMITED ; // (8 currently)
```

Check the size of the files:

```bash
du -skh /glade/derecho/scratch/$USER/archive/bhistc_high_freq/atm/hist/*
```
